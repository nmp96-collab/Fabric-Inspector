# %% [markdown]
# <a href="https://colab.research.google.com/github/nmp96-collab/Fabric-Inspector/blob/main/YOLO_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %pip install -q "ultralytics>=8.4.0" supervision roboflow

# prevent ultralytics from tracking your activity
# !yolo settings sync=False
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.9/112.6 GB disk)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

from google.colab import userdata
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="m5wGtztN6Ck6mrgRe7Ns")
project = rf.workspace("natalies-workspace-dmdzy").project("fabric-defect-fvlhp-60bee")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# /content/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to fabric-defect--1 in yolo26:: 100%|██████████| 3837/3837 [00:00<00:00, 4901.11it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo26m.pt data={dataset.location}/data.yaml epochs=20 imgsz=640 plots=True
# Out:
# /content
# ...
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/runs/detect/train/weights/best.pt" "/content/drive/MyDrive/"
